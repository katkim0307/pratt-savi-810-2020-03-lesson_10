# %% [markdown]
# # Lesson 10
#
# # In-Class Team Coding Exercise, Additional Mapping Functionality with Matplotlib
#
#
#
# ![http://www.pratt.edu/tiny_mce/plugins/imagemanager/files/Light_brown_blue22.jpg](http://www.pratt.edu/tiny_mce/plugins/imagemanager/files/Light_brown_blue22.jpg)
#
# # Class Links
#
# * [Syllabus](https://docs.google.com/document/d/1KHxT-NkaoXXdSNkK8JlzL2FFgmNoxPQ25fwgtXPnbrY)
#
# * [Class Google Spreadsheet](https://docs.google.com/spreadsheets/d/1t481r7HjQBbjNtFOABSOlcckzQhdrh12TCzpSYKurI0/edit?usp=sharing)
#
# * [Google Meetup Video Hangout](https://meet.google.com/aym-kxae-bzr)
#
#   * For United States Dial +1
#     * (669) 220-6376
#   * Enter this PIN when prompted:
#     * 891 126 706 #
#
# * [GitHub Organization](https://github.com/pratt-savi-810)
#
# * [Slack Organization](https://app.slack.com/client/T01068MA75X/C010J3Q2QET)
#
# * [Resources](https://github.com/pratt-savi-810/resources)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Lesson-10" data-toc-modified-id="Lesson-10-1">Lesson 10</a></span></li><li><span><a href="#In-Class-Team-Coding-Exercise,-Additional-Mapping-Functionality-with-Matplotlib" data-toc-modified-id="In-Class-Team-Coding-Exercise,-Additional-Mapping-Functionality-with-Matplotlib-2">In-Class Team Coding Exercise, Additional Mapping Functionality with Matplotlib</a></span></li><li><span><a href="#Class-Links" data-toc-modified-id="Class-Links-3">Class Links</a></span></li><li><span><a href="#Code-Wars---Python" data-toc-modified-id="Code-Wars---Python-4">Code Wars - Python</a></span></li><li><span><a href="#Learning-Objectives" data-toc-modified-id="Learning-Objectives-5">Learning Objectives</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Fork-and-Clone-this-Lesson-Repo" data-toc-modified-id="Fork-and-Clone-this-Lesson-Repo-5.0.1">Fork and Clone this Lesson Repo</a></span></li></ul></li></ul></li><li><span><a href="#First-off,-let's-Upgrade-some-Libraries" data-toc-modified-id="First-off,-let's-Upgrade-some-Libraries-6">First off, let's Upgrade some Libraries</a></span></li><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-7">Import Libraries</a></span></li><li><span><a href="#Python-Mapping-Guide" data-toc-modified-id="Python-Mapping-Guide-8">Python Mapping Guide</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Resources:" data-toc-modified-id="Resources:-8.0.1">Resources:</a></span></li></ul></li><li><span><a href="#Map-Elements-Example" data-toc-modified-id="Map-Elements-Example-8.1">Map Elements Example</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Let's-import-NYC-NTA-Boundaries-and-generate-a-GeoDataFrame" data-toc-modified-id="Let's-import-NYC-NTA-Boundaries-and-generate-a-GeoDataFrame-8.1.0.1">Let's import NYC NTA Boundaries and generate a GeoDataFrame</a></span></li></ul></li></ul></li><li><span><a href="#Frame-and-neat-line" data-toc-modified-id="Frame-and-neat-line-8.2">Frame and neat line</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Lets-create-a-Figure-and-add-Axes" data-toc-modified-id="Lets-create-a-Figure-and-add-Axes-8.2.0.1">Lets create a Figure and add Axes</a></span></li></ul></li></ul></li><li><span><a href="#Mapped-area-(figure)" data-toc-modified-id="Mapped-area-(figure)-8.3">Mapped area (figure)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Get-GeoDataFrames's-.bounds" data-toc-modified-id="Get-GeoDataFrames's-.bounds-8.3.0.1">Get GeoDataFrames's <code>.bounds</code></a></span></li></ul></li></ul></li><li><span><a href="#Let's-set-the-Map-extent" data-toc-modified-id="Let's-set-the-Map-extent-8.4">Let's set the Map extent</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Change-our-.set_xlim(-)" data-toc-modified-id="Change-our-.set_xlim(-)-8.4.0.1">Change our <code>.set_xlim( )</code></a></span></li><li><span><a href="#Change-our-.set_ylim(-)" data-toc-modified-id="Change-our-.set_ylim(-)-8.4.0.2">Change our <code>.set_ylim( )</code></a></span></li><li><span><a href="#Inset-Maps-Reference:-https://github.com/geopandas/geopandas/issues/1114" data-toc-modified-id="Inset-Maps-Reference:-https://github.com/geopandas/geopandas/issues/1114-8.4.0.3">Inset Maps Reference: <a href="https://github.com/geopandas/geopandas/issues/1114" target="_blank">https://github.com/geopandas/geopandas/issues/1114</a></a></span></li></ul></li></ul></li><li><span><a href="#Setting-a-Map's-Title" data-toc-modified-id="Setting-a-Map's-Title-8.5">Setting a Map's Title</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Set-the-Map-Title-by-applying-to-Axes-with-ax.set_title(-)" data-toc-modified-id="Set-the-Map-Title-by-applying-to-Axes-with-ax.set_title(-)-8.5.0.1">Set the Map Title by applying to Axes with <code>ax.set_title( )</code></a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Pickup-Here-from-Monday" data-toc-modified-id="Pickup-Here-from-Monday-9">Pickup Here from Monday</a></span><ul class="toc-item"><li><span><a href="#Legend" data-toc-modified-id="Legend-9.1">Legend</a></span></li><li><span><a href="#Annotate-Data-Source" data-toc-modified-id="Annotate-Data-Source-9.2">Annotate Data Source</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#More-on-annotation:-https://jakevdp.github.io/PythonDataScienceHandbook/04.09-text-and-annotation.html" data-toc-modified-id="More-on-annotation:-https://jakevdp.github.io/PythonDataScienceHandbook/04.09-text-and-annotation.html-9.2.0.1">More on annotation: <a href="https://jakevdp.github.io/PythonDataScienceHandbook/04.09-text-and-annotation.html" target="_blank">https://jakevdp.github.io/PythonDataScienceHandbook/04.09-text-and-annotation.html</a></a></span></li></ul></li></ul></li><li><span><a href="#Turn-off-the-axis-and-neatline" data-toc-modified-id="Turn-off-the-axis-and-neatline-9.3">Turn off the axis and neatline</a></span></li></ul></li><li><span><a href="#Basemaps-with-Contextily" data-toc-modified-id="Basemaps-with-Contextily-10">Basemaps with Contextily</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Change-the-Basemap" data-toc-modified-id="Change-the-Basemap-10.0.0.1">Change the Basemap</a></span></li><li><span><a href="#Carto-Basemaps---Positron-Light" data-toc-modified-id="Carto-Basemaps---Positron-Light-10.0.0.2">Carto Basemaps - Positron Light</a></span></li><li><span><a href="#Carto-Positron-Dark---No-Labels" data-toc-modified-id="Carto-Positron-Dark---No-Labels-10.0.0.3">Carto Positron Dark - No Labels</a></span></li><li><span><a href="#More-Carto-(CartoDB)-Basemaps" data-toc-modified-id="More-Carto-(CartoDB)-Basemaps-10.0.0.4">More Carto (CartoDB) Basemaps</a></span></li><li><span><a href="#More-Contextily-Basemaps" data-toc-modified-id="More-Contextily-Basemaps-10.0.0.5">More Contextily Basemaps</a></span></li></ul></li></ul></li><li><span><a href="#Join-our-NTA-data-to-some-Demographic-Data" data-toc-modified-id="Join-our-NTA-data-to-some-Demographic-Data-10.1">Join our NTA data to some Demographic Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Read-in-Demographic-Population-Data-2000-2010-from-NYC-DCP" data-toc-modified-id="Read-in-Demographic-Population-Data-2000-2010-from-NYC-DCP-10.1.0.1">Read in Demographic Population Data 2000-2010 from NYC DCP</a></span></li><li><span><a href="#Shape-of-the-data" data-toc-modified-id="Shape-of-the-data-10.1.0.2">Shape of the data</a></span></li><li><span><a href="#List-the-columns" data-toc-modified-id="List-the-columns-10.1.0.3">List the columns</a></span></li><li><span><a href="#Let's-merge-our-datasets" data-toc-modified-id="Let's-merge-our-datasets-10.1.0.4">Let's merge our datasets</a></span></li><li><span><a href="#Describe-our-data" data-toc-modified-id="Describe-our-data-10.1.0.5">Describe our data</a></span></li><li><span><a href="#Plot" data-toc-modified-id="Plot-10.1.0.6">Plot</a></span></li></ul></li></ul></li><li><span><a href="#Now-Let's-Make-this-Map-Better" data-toc-modified-id="Now-Let's-Make-this-Map-Better-10.2">Now Let's Make this Map Better</a></span></li></ul></li><li><span><a href="#In-Class-Team-Coding-Exercise" data-toc-modified-id="In-Class-Team-Coding-Exercise-11">In-Class Team Coding Exercise</a></span><ul class="toc-item"><li><span><a href="#Input" data-toc-modified-id="Input-11.1">Input</a></span></li><li><span><a href="#Expected-Output" data-toc-modified-id="Expected-Output-11.2">Expected Output</a></span></li></ul></li><li><span><a href="#Pizza-Analogy" data-toc-modified-id="Pizza-Analogy-12">Pizza Analogy</a></span><ul class="toc-item"><li><span><a href="#1.-Get-Pizza-Making-Ingredients" data-toc-modified-id="1.-Get-Pizza-Making-Ingredients-12.1">1. Get Pizza Making Ingredients</a></span></li><li><span><a href="#2.-Prepare-Pizza-Making-Ingredients-and-Supplies" data-toc-modified-id="2.-Prepare-Pizza-Making-Ingredients-and-Supplies-12.2">2. Prepare Pizza Making Ingredients and Supplies</a></span></li><li><span><a href="#3.-Pizza-Cooking-Steps" data-toc-modified-id="3.-Pizza-Cooking-Steps-12.3">3. Pizza Cooking Steps</a></span></li><li><span><a href="#4.-Present-Pizza-to-table" data-toc-modified-id="4.-Present-Pizza-to-table-12.4">4. Present Pizza to table</a></span></li><li><span><a href="#Creating-High-Level-Task-Functions" data-toc-modified-id="Creating-High-Level-Task-Functions-12.5">Creating High Level Task Functions</a></span></li><li><span><a href="#Back-to-Pizza" data-toc-modified-id="Back-to-Pizza-12.6">Back to Pizza</a></span></li><li><span><a href="#Next-Let's-Create-our-High-Level-Functions" data-toc-modified-id="Next-Let's-Create-our-High-Level-Functions-12.7">Next Let's Create our High Level Functions</a></span></li><li><span><a href="#Let's-dive-more-into-get_ingredients()" data-toc-modified-id="Let's-dive-more-into-get_ingredients()-12.8">Let's dive more into <code>get_ingredients()</code></a></span></li><li><span><a href="#First-let's-add-a-walk()-function-to-get-us-from-home-to-store." data-toc-modified-id="First-let's-add-a-walk()-function-to-get-us-from-home-to-store.-12.9">First let's add a <code>walk()</code> function to get us from home to store.</a></span></li><li><span><a href="#Let's-now-create-the-other-steps-inside-our-function." data-toc-modified-id="Let's-now-create-the-other-steps-inside-our-function.-12.10">Let's now create the other steps inside our function.</a></span></li><li><span><a href="#Then-our-main-script-may-look-something-like-this;" data-toc-modified-id="Then-our-main-script-may-look-something-like-this;-12.11">Then our main script may look something like this;</a></span></li></ul></li><li><span><a href="#Time-for-our-In-Class-Exercise" data-toc-modified-id="Time-for-our-In-Class-Exercise-13">Time for our In-Class Exercise</a></span></li><li><span><a href="#Gitignore-Review" data-toc-modified-id="Gitignore-Review-14">Gitignore Review</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Useful-.gitignore-file-links" data-toc-modified-id="Useful-.gitignore-file-links-14.0.0.1">Useful <code>.gitignore</code> file links</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Code Wars - Python
#
# * [Kata - Getting Started With Python!](https://www.codewars.com/collections/getting-started-with-python-1)

# %% [markdown]
# # Learning Objectives
#
#
# * Additional Mapping Functionality with Matplotlib
# * In-Class Team Coding Exercise
#
#
# ### Fork and Clone this Lesson Repo
#
# https://github.com/pratt-savi-810/pratt-savi-810-2020-03-lesson_10

# %% [markdown]
# # First off, let's Upgrade some Libraries

# %%
# !pip install geopandas --upgrade

# %%
# !pip install osmnx --upgrade

# %%
# !pip install contextily

# %% [markdown]
# # Import Libraries
#
# Let's `import` some of the libraries we've already used.

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    

from IPython.display import IFrame
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import missingno as msno
import seaborn as sns
import matplotlib.patches as patches
import warnings
import networkx as nx
import osmnx as ox
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
ox.config(use_cache=True, log_console=True)
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Python Mapping Guide

# %% [markdown]
# Slocum’s (Thematic Cartography and Geovisualization) Map Elements
# * Frame and neat line
# * Mapped area (figure)
# * Inset
# * Title and subtitle
# * Legend
# * Data source
# * Scale
# * Orientation
#
# ### Resources:
# * [GeoPandas Mapping Tools](https://geopandas.org/mapping.html)
# * [Geospatial data mapping with python](https://mohammadimranhasan.com/geospatial-data-mapping-with-python/)
#
#
# ## Map Elements Example
# ![map](https://saylordotorg.github.io/text_essentials-of-geographic-information-systems/section_13/0c71cd48743695df3cb5ca49fd858393.jpg)
# _Source: [https://saylordotorg.github.io/text_essentials-of-geographic-information-systems/s13-03-cartographic-design.html](https://saylordotorg.github.io/text_essentials-of-geographic-information-systems/s13-03-cartographic-design.html)_

# %% [markdown]
# #### Let's import NYC NTA Boundaries and generate a GeoDataFrame

# %%
nyc_nta_geojson = 'https://data.cityofnewyork.us/api/geospatial/cpf4-rkhq?method=export&format=GeoJSON'

nta_gdf = gpd.read_file(nyc_nta_geojson)
nta_gdf.to_crs(2263, inplace=True)

# %% [markdown]
# ## Frame and neat line
#
# #### Lets create a Figure and add Axes
#
# > Axes object is the region of the image with the data space. A given figure can contain many Axes, but a given Axes object can only be in one Figure. The Axes contains two (or three in the case of 3D) Axis objects. The Axes class and its member functions are the primary entry point to working with the OO interface.
#
# > Axes object is added to figure by calling the add_axes() method. It returns the axes object and adds an axes at position rect [left, bottom, width, height] where all quantities are in fractions of figure width and height. Source: https://www.tutorialspoint.com/matplotlib/matplotlib_axes_class.htm

# %%
fig, ax = plt.subplots(figsize=(14, 10))

# %% [markdown]
# ## Mapped area (figure)

# %%
fig, ax = plt.subplots(figsize=(14, 10))

nta_gdf.plot(ax=ax);

# %% [markdown]
# #### Get GeoDataFrames's `.bounds`

# %%
nta_gdf.bounds.describe().astype('int64')
# Out:
#           minx    miny     maxx    maxy
# count      195     195      195     195
# mean   1001484  197070  1011201  207178
# std      28112   34028    28071   32697
# min     913175  120121   927093  142484
# 25%     988100  170943   994926  182244
# 50%    1002831  196668  1011570  206239
# 75%    1019582  222232  1029807  230730
# max    1059349  262717  1067382  272844

# %%
fig, ax = plt.subplots(figsize=(14, 10))

nta_gdf.plot(ax=ax)

ax.set_xlim(913_175, 1_067_382)
ax.set_ylim(120_121, 272_844);

# %% [markdown]
# ## Let's set the Map extent

# %% [markdown]
# #### Change our `.set_xlim( )`

# %%
fig, ax = plt.subplots(figsize=(14, 10))

nta_gdf.plot(ax=ax)

ax.set_xlim(980_000, 1_005_000)
ax.set_ylim(120_121, 272_844);

# %% [markdown]
# #### Change our `.set_ylim( )`

# %%
fig, ax = plt.subplots(figsize=(14, 10))

nta_gdf.plot(ax=ax)

ax.set_xlim(980_000, 1_005_000)
ax.set_ylim(190_000, 210_000);

# %% [markdown]
# #### Inset Maps Reference: https://github.com/geopandas/geopandas/issues/1114

# %% [markdown]
# ## Setting a Map's Title
#
# Set with `plt.title( )`

# %%
fig, ax = plt.subplots(figsize=(14, 10))

nta_gdf.plot(ax=ax)

ax.set_xlim(980_000, 1_005_000)
ax.set_ylim(190_000, 210_000);

plt.title('Map Title', fontdict={'size': 30});

# %% [markdown]
# #### Set the Map Title by applying to Axes with `ax.set_title( )`

# %%
fig, ax = plt.subplots(figsize=(14, 10))

nta_gdf.plot(ax=ax)

ax.set_xlim(980_000, 1_005_000)
ax.set_ylim(190_000, 210_000);

ax.set_title('Map Title', fontdict={'size': 30});

# %% [markdown]
# # Pickup Here from Monday
#
# ## Legend
#
# PyPlot Legends : https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.legend.html

# %%
fig, ax = plt.subplots(figsize=(14, 10))

# %% [markdown]
# ## Annotate Data Source

# %% [markdown]
# #### More on annotation: https://jakevdp.github.io/PythonDataScienceHandbook/04.09-text-and-annotation.html

# %% [markdown]
# ## Turn off the axis and neatline

# %% [markdown]
# # Basemaps with Contextily
#
# > contextily is a small Python 3 package to retrieve and write to disk tile maps from the internet into geospatial raster files. Bounding boxes can be passed in both WGS84 (EPSG:4326) and Spheric Mercator (EPSG:3857). See the notebook contextily_guide.ipynb for usage. Source: https://github.com/darribas/contextily

# %%
# import as ctx

# %% [markdown]
# #### Change the Basemap

# %% [markdown]
# #### Carto Basemaps - Positron Light

# %% [markdown]
# #### Carto Positron Dark - No Labels

# %% [markdown]
# #### More Carto (CartoDB) Basemaps
#
# https://github.com/CartoDB/basemap-styles
#
#
# #### More Contextily Basemaps
#
# https://github.com/darribas/contextily/blob/master/contextily/tile_providers.py

# %% [markdown]
# ## Join our NTA data to some Demographic Data

# %% [markdown]
# #### Read in Demographic Population Data 2000-2010 from NYC DCP

# %% [markdown]
# #### Shape of the data

# %% [markdown]
# #### List the columns

# %% [markdown]
# #### Let's merge our datasets

# %% [markdown]
# #### Describe our data

# %% [markdown]
# #### Plot

# %% [markdown]
# ## Now Let's Make this Map Better

# %% [markdown]
# # In-Class Team Coding Exercise
#
# ## Input
# You will be given a set of addresses.
#
# ## Expected Output
# It is expected you will output a set of maps.

# %% [markdown]
# # Pizza Analogy
#
# ![pizza](https://media.timeout.com/images/105294390/630/472/image.jpg)
#
# When preparing and making some food or some dish you need to divide the tasks into a  hierarchy of tasks and then split those tasks up into the individual steps.
#
# So below we've outlined some of the steps necessary to make pizza at home.
#
#
# ## 1. Get Pizza Making Ingredients
# * Go to store
# * Get dough off shelf
#     * Place dough in cart
# * Get sauce off shelf
#     * Place sauce in cart
# * Get cheese off shelf
#     * Place cheese in cart (repetitive, 🤔 - could I use some Python trick here?)
# * Checkout at register
# * Carry ingredients in grocery bag to kitchen
#
#
#
# ## 2. Prepare Pizza Making Ingredients and Supplies
# * For dough
#     * Remove dough from grocery bag.
# * For sauce
#     * Remove Sauce from grocery bag.
# * For cheese
#     * Remove cheese from grocery bag. (repetitive, 🤔 - could I use some Python trick here?)
# * For item in `[dough, sauce, cheese]`:
#     * Place item on kitchen counter
# * For item in `[dough, sauce, cheese]`:
#     * Open item from packaging
# * For item in `[dough, sauce, cheese]`:
#     * Place item on pizza sheet
#
# ## 3. Pizza Cooking Steps
# * Set oven to 450° F
# * While oven < 450° F
#     * Wait, when True, pass to next step
# * While cheese is not melted:
#     * Wait, when True, pass to next step
# * When cheese is melted:
#     * Turn oven off
#
#
# ## 4. Present Pizza to table
# * Place oven mits on hands
# * Carefully remove pizza from oven
# * While pizza too hot to serve:
#     * Wait
# * When pizza at serving temperature
#     * Slice with pizza cutter
# * Carry pizza tray to dining table

# %% [markdown]
# ## Creating High Level Task Functions
#
# For a refresh, here's how a function is structured.
#
# ```python
#
# def a_function(argument_1, argument_2):
#     new_variable = do_something(argument_1, argument_2)
#     return new_variable
#
# ```
#
# Within a function, you can also have loops inside of a function.
#
# ```python
#
# def a_function(argument_1_list, argument_2):
#     result_list = []
#
#     for list_item in argument_1_list:
#         result_list.append(
#             do_something(argument_1, argument_2)
#         )
#
#     return result_list
#
# ```
#
#
# Or have a loop occur loops outside of a function.
#
# ```python
#
# def a_function(argument_1, argument_2):
#     return do_something(argument_1, argument_2)
#
#
# result_list = []
#
# for item in list_of_items:
#     result_list.append(
#         a_function(item, argument_2)
#     )
#
# result_list
#
# ```

# %% [markdown]
# ## Back to Pizza
#
# Here we have our steps commented out.

# %% [markdown]
# ```python
#
# # ## 1. Get Pizza Making Ingredients
# # * Go to store
# # * Get dough off shelf
# #     * Place dough in cart
# # * Get sauce off shelf
# #     * Place sauce in cart
# # * Get cheese off shelf
# #     * Place cheese in cart (repetitive, 🤔 - could I use some Python trick here?)
# # * Checkout at register
# # * Carry ingredients in grocery bag to kitchen
#
# # ## 2. Prepare Pizza Making Ingredients and Supplies
# # * For dough
# #     * Remove dough from grocery bag.
# # * For sauce
# #     * Remove Sauce from grocery bag.
# # * For cheese
# #     * Remove cheese from grocery bag. (repetitive, 🤔 - could I use some Python trick here?)
# # * For item in `[dough, sauce, cheese]`:
# #     * Place item on kitchen counter
# # * For item in `[dough, sauce, cheese]`:
# #     * Open item from packaging
# # * For item in `[dough, sauce, cheese]`:
# #     * Place item on pizza sheet
#
# # ## 3. Pizza Cooking Steps
# # * Set oven to 450° F
# # * While oven < 450° F
# #     * Wait, when True, pass to next step
# # * While cheese is not melted:
# #     * Wait, when True, pass to next step
# # * When cheese is melted:
# #     * Turn oven off
#
#
# # ## 4. Present Pizza to table
# # * Place oven mits on hands
# # * Carefully remove pizza from oven
# # * While pizza too hot to serve:
# #     * Wait
# # * When pizza at serving temperature
# #     * Slice with pizza cutter
# # * Carry pizza tray to dining table
#
#
# ```

# %% [markdown]
# ## Next Let's Create our High Level Functions

# %% [markdown]
# ```python
# def get_ingredients():
#     pass
# # * Go to store
# # * Get dough off shelf
# #     * Place dough in cart
# # * Get sauce off shelf
# #     * Place sauce in cart
# # * Get cheese off shelf
# #     * Place cheese in cart (repetitive, 🤔 - could I use some Python trick here?)
# # * Checkout at register
# # * Carry ingredients in grocery bag to kitchen
#
# def prepare_ingredients():
#     pass
# # * For dough
# #     * Remove dough from grocery bag.
# # * For sauce
# #     * Remove Sauce from grocery bag.
# # * For cheese
# #     * Remove cheese from grocery bag. (repetitive, 🤔 - could I use some Python trick here?)
# # * For item in `[dough, sauce, cheese]`:
# #     * Place item on kitchen counter
# # * For item in `[dough, sauce, cheese]`:
# #     * Open item from packaging
# # * For item in `[dough, sauce, cheese]`:
# #     * Place item on pizza sheet
#
# def cook_pizza():
#     pass
# # * Set oven to 450° F
# # * While oven < 450° F
# #     * Wait, when True, pass to next step
# # * While cheese is not melted:
# #     * Wait, when True, pass to next step
# # * When cheese is melted:
# #     * Turn oven off
#
#
# def serve_pizza():
#     pass
# # * Place oven mits on hands
# # * Carefully remove pizza from oven
# # * While pizza too hot to serve:
# #     * Wait
# # * When pizza at serving temperature
# #     * Slice with pizza cutter
# # * Carry pizza tray to dining table
#
#
# ```

# %% [markdown]
# ## Let's dive more into `get_ingredients()`

# %% [markdown]
# ```python
# def get_ingredients():
#     pass
# # * Go to store
# # * Get dough off shelf
# #     * Place dough in cart
# # * Get sauce off shelf
# #     * Place sauce in cart
# # * Get cheese off shelf
# #     * Place cheese in cart (repetitive, 🤔 - could I use some Python trick here?)
# # * Checkout at register
# # * Carry ingredients in grocery bag to kitchen
# ```

# %% [markdown]
# ## First let's add a `walk()` function to get us from home to store.
#
# ```python
# from travel import walk
#
# def get_ingredients(home, store):
#     walk(home, store)
#
# # * Go to store
# # * Get dough off shelf
# #     * Place dough in cart
# # * Get sauce off shelf
# #     * Place sauce in cart
# # * Get cheese off shelf
# #     * Place cheese in cart (repetitive, 🤔 - could I use some Python trick here?)
# # * Checkout at register
# # * Carry ingredients in grocery bag to kitchen
# ```

# %% [markdown]
# ## Let's now create the other steps inside our function.

# %% [markdown]
# ```python
# from travel import walk
# from store_actions import grab_off_shelf, place_on_register, checkout
#
#
# def get_ingredients(home, store, items_list):
#     walk(home, store)
#
#     items_in_cart = []
#     for item in items_list:
#
#         item_in_hand = grab_off_shelf(item)  # Get dough off shelf
#
#         items_in_cart.append(
#             item_in_hand
#         )  # Place item in cart
#
#     bag_items = []
#     for item in items_in_cart:
#
#         place_on_register(item)
#
#         checkout(item)  # Checkout at register
#
#         bag_items.append(item)
#
#     walk(store, home)  # * Carry ingredients in grocery bag to kitchen
#
#     return bag_items
#
# ```
#
# Let's say we save this function in a file called `procure_ingredients.py`.
#
# So in the top level function, I may pass in the followin for our `get_ingredients()` function as follows;
#
# ```python
#
# groceries = get_ingredients(
#     '144 W 14th St, New York, NY',
#     "Trader Joe's 142 E 14th St, New York, NY 10003",
#     ['dough', 'sauce', 'mozzarella cheese']
# )
#
# ```

# %% [markdown]
# ## Then our main script may look something like this;
#
# ```python
#
# # import our functions
# from procure_ingredients import get_ingredients
# from preparation import prepare_ingredients
# from cooking import cook_pizza
# from serving import serve_pizza
#
# ingredients_as_groceries = get_ingredients(
#     '144 W 14th St, New York, NY',
#     "Trader Joe's 142 E 14th St, New York, NY 10003",
#     ['dough', 'sauce', 'mozzarella cheese']
# )
#
# prepared_pizza = prepare_ingredients(ingredients_as_groceries)
# # returns ingredients on tray
#
# cooked_pizza = cook_pizza(prepared_pizza)
# # returns cooked pizza
#
# serve_pizza('144 W 14th St, New York, NY')
# # serves pizza to some hungry folks at this address
#
#
# ```

# %% [markdown]
# # Time for our In-Class Exercise
#
# https://github.com/pratt-savi-810/pratt-savi-810-2020-03-activity_01/issues
#
# This program should;
#
# 1. Take in a `.csv` of addresses.
# 2. Geocode these addresses.
# 3. Find out what states these addresses are in.
# 4. Download and unzip those state Census Tract shapefiles
# 5. Buffer the addresses by a given Buffer distance (2 km)
# 6. Intersect and perform area-weighted interpolation to estimate population within Buffer distance
# 7. Sum the population in Buffer
# 8. Print maps of the geocoded address, tract boundaries and buffers.

# %%
import random

files = [
    'buffer_points.py', 
    'census_tract_shapefiles.py',
    'geocode.py',
    'mapping.py',
    'state_ids.py',
]

students = ['Sara', 'Anna', 'Roger', 'Kat', 'Mattrew']

random.shuffle(files)
random.shuffle(students)

print(files)
print(students)
# Out:
# ['geocode.py', 'census_tract_shapefiles.py', 'mapping.py', 'buffer_points.py', 'state_ids.py']
# ['Kat', 'Sara', 'Anna', 'Mattrew', 'Roger']

# %%
for student, code_file in zip(students, files):
    print(f'{student} - {code_file}')
# Out:
# Kat - geocode.py
# Sara - census_tract_shapefiles.py
# Anna - mapping.py
# Mattrew - buffer_points.py
# Roger - state_ids.py

# %% [markdown]
# # Gitignore Review
#
# > A gitignore file specifies intentionally untracked files that Git should ignore. Files already tracked by Git are not affected... Each line in a gitignore file specifies a pattern. Source: https://git-scm.com/docs/gitignore
#
# ![gitignore](https://i.stack.imgur.com/coZgL.png)
# _Source: [https://stackoverflow.com/questions/29618048/file-shows-up-in-the-list-of-files-to-commit-in-github-for-windows-whereas-it-is](https://stackoverflow.com/questions/29618048/file-shows-up-in-the-list-of-files-to-commit-in-github-for-windows-whereas-it-is)_
#
# #### Useful `.gitignore` file links
# * https://git-scm.com/docs/gitignore
# * https://help.github.com/en/github/using-git/ignoring-files
